# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import ast
from mplsoccer import VerticalPitch
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.image as image
from statsbombpy import sb
import os

# %%
events = sb.events (match_id = 3893796)
df = events[events.type == 'Shot']
df = df[['period', 'minute', 'shot_statsbomb_xg', 'team', 'player', 'shot_outcome' ]]
df.rename(columns = {'shot_statsbomb_xg':'xG', 'shot_outcome':'result'}, inplace = True)
df.sort_values(by='team', inplace=True)
df
# Out:
#       period  minute        xG                  team  \
# 3095       1       5  0.032486  South Africa Women's
# 3118       2      92  0.038958  South Africa Women's
# 3117       2      92  0.044685  South Africa Women's
# 3116       2      90  0.018721  South Africa Women's
# 3106       2      47  0.067578  South Africa Women's
# 3105       1      48  0.037923  South Africa Women's
# 3107       2      47  0.704797  South Africa Women's
# 3096       1      15  0.007656  South Africa Women's
# 3100       1      29  0.019329  South Africa Women's
# 3099       1      27  0.064571  South Africa Women's
# 3102       1      42  0.138347        Sweden Women's
# 3097       1      19  0.041146        Sweden Women's
# 3098       1      22  0.108474        Sweden Women's
# 3115       2      89  0.179357        Sweden Women's
# 3114       2      84  0.027353        Sweden Women's
# 3113       2      74  0.058698        Sweden Women's
# 3112       2      64  0.299106        Sweden Women's
# 3111       2      63  0.046317        Sweden Women's
# 3110       2      59  0.141037        Sweden Women's
# 3109       2      59  0.062347        Sweden Women's
# 3108       2      52  0.007570        Sweden Women's
# 3119       2      94  0.044970        Sweden Women's
# 3104       1      45  0.028469        Sweden Women's
# 3103       1      42  0.204244        Sweden Women's
# 3101       1      31  0.071212        Sweden Women's
# 3120       2      95  0.145451        Sweden Women's
#
#                              player   result
# 3095                 Kholosa Biyana    Off T
# 3118       Bambanani Nolufefe Mbane    Saved
# 3117                Thembi Kgatlana  Blocked
# 3116          Mapula Nomvula Kgoale    Off T
# 3106                Thembi Kgatlana    Saved
# 3105                Thembi Kgatlana    Off T
# 3107        Hildah Tholakele Magaia     Goal
# 3096                   Refiloe Jane    Off T
# 3100            Jermaine Seoposenwe    Saved
# 3099                Thembi Kgatlana    Off T
# 3102                Amanda Ilestedt    Off T
# 3097        Ingrid Filippa Angeldal    Saved
# 3098        Emma Stina Blackstenius    Off T
# 3115                Amanda Ilestedt     Goal
# 3114              Rebecka Blomqvist  Wayward
# 3113                Amanda Ilestedt    Saved
# 3112                Fridolina Rolfö     Goal
# 3111       Magdalena Lilly Eriksson    Off T
# 3110                Amanda Ilestedt    Saved
# 3109        Ingrid Filippa Angeldal  Blocked
# 3108        Ingrid Filippa Angeldal    Off T
# 3119  Jonna Ann-Charlotte Andersson  Blocked
# 3104  Elin Ingrid Johanna Rubensson    Off T
# 3103                Amanda Ilestedt    Off T
# 3101        Ingrid Filippa Angeldal  Blocked
# 3120            Sara Caroline Seger    Saved

# %%
south_africa_shots = df[df['team'] == "South Africa Women's"]

# 计算南非女足的总xG
total_xG_south_africa = south_africa_shots['xG'].sum()
total_xG_south_africa
# Out:
# 1.036704651
